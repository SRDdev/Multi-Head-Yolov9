# %% [markdown]
# # MultiHead Yolov9
#
# The notebook provides a simple training script for training a modified YOLOv9-c model for clothes detection and instance segmentation.

# %% [markdown]
# Install the required libraries and clone the git repo

# %%
! pip install roboflow -q
! git clone https://github.com/SRDdev/Multi-Head-Yolov9.git
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 1.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 6.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 7.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 6.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 16.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 4.9 MB/s eta 0:00:00
# Cloning into 'Multi-Head-Yolov9'...
# remote: Enumerating objects: 155, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 155 (delta 3), reused 22 (delta 3), pack-reused 132
# Receiving objects: 100% (155/155), 141.96 MiB | 32.84 MiB/s, done.
# Resolving deltas: 100% (41/41), done.
# Updating files: 100% (119/119), done.

# %%
#Get data
from roboflow import Roboflow
from google.colab import userdata

def get_data(api):
  rf = Roboflow(api_key=api)
  project = rf.workspace("srddev").project("deepfashion2-bfwof")
  version = project.version(1)
  dataset = version.download("yolov9")

get_data(userdata.get('roboflow'))
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to DeepFashion2-1 in yolov9:: 100%|██████████| 1168/1168 [00:00<00:00, 7384.86it/s]

# %% [markdown]
# Now that we have the data, lets train the model using a single config file.
#
# before training the model , remember to change the paths of test,train,valid images in the `/content/DeepFashion2-1/data.yaml` file. We need to do this as we are working in colab.

# %%
# !python /content/Multi-Head-Yolov9/src/yolov9/segment/train.py --config-file /content/config.yaml
# Out:
# 2024-05-04 20:58:31.408759: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-04 20:58:31.408831: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-04 20:58:31.410202: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-04 20:58:32.439298: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...

# %%
import zipfile
import os
def zip_folder(folder_path, zip_path):
    with zipfile.ZipFile(zip_path, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for root, _, files in os.walk(folder_path):
            for file in files:
                zipf.write(os.path.join(root, file), os.path.relpath(os.path.join(root, file), os.path.join(folder_path, '..')))

zip_folder('/content/runs/train-seg', '/content/output.zip')
